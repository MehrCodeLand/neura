# %%
from PIL import Image

Image.open('../staff/nn__1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2004x772>

# %%
inputs = [ 255 , 0 , 0 , 200 ]

# %%
weights = [[ 0.5 , -0.05 , 1.1 , 3.0 ],
           [ 4.4 , 2.8 , -6.2 , 0.3 ],
           [  -7.7 , 0.6 , 1.1 , 5.5 ] ]

bias = [3 , 0.5 , 0.5 ]

len(weights) , len(weights[0])
# Out:
# (3, 4)

# %%
results = []
neuron_result = 0

# %%
for i in range(len(weights)):
    current_weight = weights[i]
    for j in range(len(inputs)):
        input = inputs[j]
        print(f"{input}")
# Out:
# 0.5
# -0.05
# 1.1
# 3.0
# 4.4
# 2.8
# -6.2
# 0.3
# -7.7
# 0.6
# 1.1
# 5.5
